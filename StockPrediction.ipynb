# %% [markdown]
# <a href="https://colab.research.google.com/github/samblaha/Stock-Prediction/blob/main/StockPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install TFANN
# Out:
# Collecting TFANN
#   Downloading https://files.pythonhosted.org/packages/a5/76/14abc62beaf0950718694744e462dfa3899ddd286c018c0771b1e00f4c8f/TFANN-1.0.1.tar.gz
# Building wheels for collected packages: TFANN
#   Building wheel for TFANN (setup.py) ... done
#   Created wheel for TFANN: filename=TFANN-1.0.1-cp36-none-any.whl size=7539 sha256=939c359a28a1d8419479211155efa5eb763aa1ab35edfd7a57909406b5a27ca3
#   Stored in directory: /root/.cache/pip/wheels/3b/38/aa/a57c9b8bdeccf63d4a14ced9ab09a1b4cc4cb3b48fadecf906
# Successfully built TFANN
# Installing collected packages: TFANN
# Successfully installed TFANN-1.0.1

# %%
import numpy as np
import matplotlib.pyplot as mpl
from sklearn.preprocessing import scale
from TFANN import ANNR
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-77870f74-da9c-41e6-a7b6-37affe0b61ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77870f74-da9c-41e6-a7b6-37affe0b61ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TOKE.csv to TOKE.csv
# {'TOKE.csv': b'Date,Date,Open,High,Low,Close,Adj Close,Volume\r\n11/25/2019,43794,16,16,15.61,15.61,14.621327,6100\r\n11/26/2019,43795,15.64,15.654,15.299,15.44,14.462094,17600\r\n11/27/2019,43796,15.56,15.67,15.52,15.598,14.610086,8600\r\n11/29/2019,43798,15.55,15.62,15.39,15.535,14.551078,8400\r\n12/2/2019,43801,15.505,15.58,15.24,15.26,14.293495,9900\r\n12/3/2019,43802,15.23,15.296,15.11,15.292,14.323468,7400\r\n12/4/2019,43803,15.46,15.46,15.23,15.23,14.265394,11700\r\n12/5/2019,43804,15.14,15.17,15.002,15.016,14.064949,14900\r\n12/6/2019,43805,15.16,15.16,14.89,14.936,13.990015,18800\r\n12/9/2019,43808,14.94,15.37,14.94,15.22,14.256028,7800\r\n12/10/2019,43809,15.35,15.35,15.025,15.078,14.123022,6200\r\n12/11/2019,43810,15.08,15.08,14.98,15.003,14.052772,7200\r\n12/12/2019,43811,14.98,15.39,14.98,15.39,14.415262,6700\r\n12/13/2019,43812,15.58,15.737,15.475,15.525,14.541709,9100\r\n12/16/2019,43815,15.42,15.589,15.42,15.468,14.48832,5200\r\n12/17/2019,43816,15.256,15.256,15.11,15.217,14.253218,11400\r\n12/18/2019,43817,15.05,15.05,14.85,14.895,13.951612,16000\r\n12/19/2019,43818,14.83,15.145,14.81,15.03,14.078063,13000\r\n12/20/2019,43819,15.03,15.149,14.918,15.05,14.096795,7500\r\n12/23/2019,43822,15.06,15.06,14.86,14.894,13.950676,14700\r\n12/24/2019,43823,14.99,14.99,14.872,14.95,14.003129,3500\r\n12/26/2019,43825,15,15,14.631,14.725,14.019315,14900\r\n12/27/2019,43826,14.68,14.74,14.6,14.71,14.005034,14500\r\n12/30/2019,43829,14.73,14.73,14.55,14.57,13.871742,22400\r\n12/31/2019,43830,14.61,15.32,14.5,15.22,14.490592,34300\r\n1/2/2020,43832,15.41,15.41,14.956,15.2,14.47155,17500\r\n1/3/2020,43833,15.133,15.133,15.035,15.07,14.347781,2900\r\n1/6/2020,43836,15.25,15.25,14.75,14.835,14.124043,8900\r\n1/7/2020,43837,14.82,14.865,14.52,14.559,13.86127,15200\r\n1/8/2020,43838,14.5,14.745,14.325,14.633,13.931724,11300\r\n1/9/2020,43839,14.7,14.87,14.665,14.854,14.142133,6700\r\n1/10/2020,43840,14.89,14.89,14.7,14.706,14.001225,11200\r\n1/13/2020,43843,14.79,15.225,14.6,15.225,14.495353,6600\r\n1/14/2020,43844,15.2,15.53,14.98,15.419,14.680055,22000\r\n1/15/2020,43845,15.65,16.299999,15.591,16.212999,15.436002,12600\r\n1/16/2020,43846,16.475,16.620001,16.219999,16.323999,15.541684,23900\r\n1/17/2020,43847,16.440001,16.457001,16.191999,16.43,15.642604,10600\r\n1/21/2020,43851,16.52,16.67,16.08,16.09,15.318898,30500\r\n1/22/2020,43852,16.299999,16.469999,16.09,16.34,15.556916,14300\r\n1/23/2020,43853,16.290001,16.51,16.231001,16.370001,15.585479,5000\r\n1/24/2020,43854,16.41,16.41,15.56,15.65,14.899983,11100\r\n1/27/2020,43857,15.36,15.36,15.05,15.151,14.424898,4900\r\n1/28/2020,43858,15.25,15.464,15.182,15.446,14.705762,5100\r\n1/29/2020,43859,15.58,15.58,15.27,15.27,14.538197,6500\r\n1/30/2020,43860,15.15,15.15,15.01,15.121,14.396338,6400\r\n1/31/2020,43861,14.93,15,14.68,14.745,14.038357,12600\r\n2/3/2020,43864,14.73,14.834,14.59,14.66,13.957429,4400\r\n2/4/2020,43865,14.73,15.049,14.64,14.895,14.181168,9000\r\n2/5/2020,43866,14.932,14.932,14.712,14.785,14.076439,4900\r\n2/6/2020,43867,14.79,14.79,14.67,14.67,13.966951,11800\r\n2/7/2020,43868,14.47,14.5,14.212,14.291,13.606113,9700\r\n2/10/2020,43871,14.33,14.33,14.02,14.02,13.348103,14000\r\n2/11/2020,43872,14.09,14.254,14,14.177,13.497578,8300\r\n2/12/2020,43873,14.31,14.31,13.89,13.95,13.281456,9300\r\n2/13/2020,43874,13.88,14,13.81,13.931,13.263367,11000\r\n2/14/2020,43875,14.39,14.455,14.15,14.406,13.715602,7600\r\n2/18/2020,43879,14.45,14.452,14.306,14.369,13.680375,8100\r\n2/19/2020,43880,14.47,14.47,14.377,14.47,13.776536,4600\r\n2/20/2020,43881,14.54,14.954,14.54,14.678,13.974567,3900\r\n2/21/2020,43882,14.67,14.67,14.48,14.48,13.786055,2200\r\n2/24/2020,43885,14,14,13.78,13.81,13.148166,14300\r\n2/25/2020,43886,13.924,13.95,13.267,13.295,12.657846,6900\r\n2/26/2020,43887,13.19,13.451,13.11,13.149,12.518844,9600\r\n2/27/2020,43888,12.81,12.838,12.21,12.53,11.929508,11300\r\n2/28/2020,43889,12,12.413,11.82,12.413,11.818116,11300\r\n3/2/2020,43892,12.54,12.552,12.25,12 ...

# %%
#reads data from the file and ceates a matrix with only the dates and the prices 
stock_data = np.loadtxt('TOKE.csv', delimiter=",", skiprows=1, usecols=(1, 4))
#scales the data to smaller values
stock_data=scale(stock_data)
#gets the price and dates from the matrix
prices = stock_data[:, 1].reshape(-1, 1)
dates = stock_data[:, 0].reshape(-1, 1)
#creates a plot of the data and then displays it
mpl.plot(dates[:, 0], prices[:, 0])
mpl.show()

# %%
#Number of neurons in the input, output, and hidden layers
input = 1
output = 1
hidden = 50
#array of layers, 3 hidden and 1 output, along with the tanh activation function 
layers = [('F', hidden), ('AF', 'tanh'), ('F', hidden), ('AF', 'tanh'), ('F', hidden), ('AF', 'tanh'), ('F', output)]
#construct the model and dictate params
mlpr = ANNR([input], layers, batchSize = 256, maxIter = 20000, tol = 0.2, reg = 1e-4, verbose = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8abe866008f4> in <module>()
#       6 layers = [('F', hidden), ('AF', 'tanh'), ('F', hidden), ('AF', 'tanh'), ('F', hidden), ('AF', 'tanh'), ('F', output)]
#       7 #construct the model and dictate params
# ----> 8 mlpr = ANNR([input], layers, batchSize = 256, maxIter = 20000, tol = 0.2, reg = 1e-4, verbose = True)
#
# /usr/local/lib/python3.6/dist-packages/TFANN.py in __init__(self, _IS, _NA, batchSize, learnRate, loss, maxIter, name, optmzrn, pad, reg, tol, verbose, X, Y)
#     209         self.O = None
#     210         self.TFVar = None
# --> 211         with tf.variable_scope(self.name):
#     212             self.TFVar = set(tf.global_variables())                 #All variables before model
#     213             self.CreateModel()                                      #Populate TensorFlow graph
#
# AttributeError: module 'tensorflow' has no attribute 'variable_scope'
